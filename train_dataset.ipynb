# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use('ggplot')

# %%
df=pd.read_csv('/content/train_data.csv')
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 3494              Hyundai Verna 1.6 SX   Hyderabad  2012              83678
# 3495          Maruti Wagon R LXI BS IV        Pune  2010              91000
# 3496       Maruti Ertiga SHVS ZDI Plus      Jaipur  2016              50000
# 3497   Hyundai Xcent 1.1 CRDi S Option       Delhi  2015              58000
# 3498                  Maruti Swift VDI      Jaipur  2012              80000
#
# ...

# %%
df['New_Price'].unique
# Out:
# <bound method Series.unique of 0               0
# 1               0
# 2       8.61 Lakh
# 3               0
# 4               0
#           ...
# 3494            0
# 3495            0
# 3496            0
# 3497            0
# 3498            0
# Name: New_Price, Length: 3499, dtype: object>

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %%
df.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                 22
# Power                  22
# Seats                  25
# New_Price            3018
# Price                   0
# dtype: int64

# %%
df['Year'].unique
# Out:
# <bound method Series.unique of 0       2010
# 1       2015
# 2       2011
# 3       2012
# 4       2013
#         ...
# 3494    2012
# 3495    2010
# 3496    2016
# 3497    2015
# 3498    2012
# Name: Year, Length: 3499, dtype: int64>

# %%
df.shape
# Out:
# (3499, 13)

# %%
a=df['New_Price'].mode

# %%
df['New_Price'].fillna(value=a, inplace=True)

# %%
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 3494              Hyundai Verna 1.6 SX   Hyderabad  2012              83678
# 3495          Maruti Wagon R LXI BS IV        Pune  2010              91000
# 3496       Maruti Ertiga SHVS ZDI Plus      Jaipur  2016              50000
# 3497   Hyundai Xcent 1.1 CRDi S Option       Delhi  2015              58000
# 3498                  Maruti Swift VDI      Jaipur  2012              80000
#
# ...

# %%
df.drop(['New_Price'],axis =1)
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 3494              Hyundai Verna 1.6 SX   Hyderabad  2012              83678
# 3495          Maruti Wagon R LXI BS IV        Pune  2010              91000
# 3496       Maruti Ertiga SHVS ZDI Plus      Jaipur  2016              50000
# 3497   Hyundai Xcent 1.1 CRDi S Option       Delhi  2015              58000
# 3498                  Maruti Swift VDI      Jaipur  2012              80000
#
# ...

# %%
df['Mileage'] = df['Mileage'].str[:-5]

# %%
df['Mileage'] = df['Mileage'].astype(str).astype(float)

# %%
df['Mileage'].mean()
# Out:
# 18.083586739068306

# %%
df['Engine'] = df['Engine'].str[:-2]

# %%
df['Engine'] = df['Engine'].astype(str).astype(float)

# %%
df['Engine'].mean()
# Out:
# 1622.2286453839517

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3499 entries, 0 to 3498
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               3499 non-null   object
#  1   Location           3499 non-null   object
#  2   Year               3499 non-null   int64
#  3   Kilometers_Driven  3499 non-null   int64
#  4   Fuel_Type          3499 non-null   object
#  5   Transmission       3499 non-null   object
#  6   Owner_Type         3499 non-null   object
#  7   Mileage            3499 non-null   float64
#  8   Engine             3477 non-null   float64
#  9   Power              3477 non-null   object
#  10  Seats              3499 non-null   object
#  11  New_Price          481 non-null    object
#  12  Price              3499 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 355.5+ KB

# %%
df['Power'] = df['Power'].str[:-3]

# %%
df['Power'].unique()
# Out:
# array(['58.16 ', '126.2 ', '88.7 ', '88.76 ', '140.8 ', '55.2 ', '63.1 ',
#        '171.5 ', '103.6 ', '74 ', '103.25 ', '116.3 ', '187.7 ', '115 ',
#        '175.56 ', '98.6 ', '83.8 ', '167.62 ', '190 ', '88.5 ', '177.01 ',
#        '80 ', '67.1 ', '102 ', '108.45 ', '138.1 ', '184 ', '179.5 ',
#        '103.5 ', '64 ', '82 ', '254.8 ', '73.9 ', '46.3 ', '37.5 ', '77 ',
#        '82.9 ', '149.92 ', '138.03 ', '112.2 ', '163.7 ', '71 ', '105 ',
#        '174.33 ', '75 ', '103.2 ', '53.3 ', '78.9 ', '147.6 ', '147.8 ',
#        '68 ', '186 ', '170 ', '69 ', '140 ', '78 ', '194 ', '500 ',
# %%
df['Year'].unique
# Out:
# <bound method Series.unique of 0       2010
# 1       2015
# 2       2011
# 3       2012
# 4       2013
#         ...
# 3494    2012
# 3495    2010
# 3496    2016
# 3497    2015
# 3498    2012
# Name: Year, Length: 3499, dtype: int64>

# %%
df[df['Power']!='null']
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 3494              Hyundai Verna 1.6 SX   Hyderabad  2012              83678
# 3495          Maruti Wagon R LXI BS IV        Pune  2010              91000
# 3496       Maruti Ertiga SHVS ZDI Plus      Jaipur  2016              50000
# 3497   Hyundai Xcent 1.1 CRDi S Option       Delhi  2015              58000
# 3498                  Maruti Swift VDI      Jaipur  2012              80000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3499 entries, 0 to 3498
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               3499 non-null   object
#  1   Location           3499 non-null   object
#  2   Year               3499 non-null   int64
#  3   Kilometers_Driven  3499 non-null   int64
#  4   Fuel_Type          3499 non-null   object
#  5   Transmission       3499 non-null   object
#  6   Owner_Type         3499 non-null   object
#  7   Mileage            3499 non-null   float64
#  8   Engine             3477 non-null   float64
#  9   Power              3499 non-null   object
#  10  Seats              3499 non-null   object
#  11  New_Price          481 non-null    object
#  12  Price              3499 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 355.5+ KB

# %%
df['Transmission'].replace(['Manual', 'Automatic'],
                        [0, 1], inplace=True)

# %%
df['Transmission']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 3494    0
# 3495    0
# 3496    0
# 3497    0
# 3498    0
# Name: Transmission, Length: 3499, dtype: int64

# %%
df['Name'].str.split().str.slice(0,3).str.join(' ')
# Out:
# 0           Maruti Wagon R
# 1        Hyundai Creta 1.6
# 2             Honda Jazz V
# 3        Maruti Ertiga VDI
# 4              Audi A4 New
#                ...
# 3494     Hyundai Verna 1.6
# 3495        Maruti Wagon R
# 3496    Maruti Ertiga SHVS
# 3497     Hyundai Xcent 1.1
# 3498      Maruti Swift VDI
# Name: Name, Length: 3499, dtype: object

# %%
df.reset_index(drop =True)
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 3494              Hyundai Verna 1.6 SX   Hyderabad  2012              83678
# 3495          Maruti Wagon R LXI BS IV        Pune  2010              91000
# 3496       Maruti Ertiga SHVS ZDI Plus      Jaipur  2016              50000
# 3497   Hyundai Xcent 1.1 CRDi S Option       Delhi  2015              58000
# 3498                  Maruti Swift VDI      Jaipur  2012              80000
#
# ...

# %%
df['Price'].mean()
# Out:
# 9.605247213489568

# %%
df.describe()
# Out:
#               Year  Kilometers_Driven  Transmission      Mileage       Engine  \
# count  3499.000000       3.499000e+03   3499.000000  3499.000000  3477.000000
# mean   2013.373821       5.979420e+04      0.286939    18.083587  1622.228645
# std       3.223566       1.160794e+05      0.452398     4.598651   589.668709
# min    1998.000000       1.710000e+02      0.000000     0.000000   624.000000
# 25%    2011.000000       3.400000e+04      0.000000    15.100000  1198.000000
# 50%    2014.000000       5.344200e+04      0.000000    18.160000  1493.000000
# 75%    2016.000000       7.303650e+04      1.000000    21.020000  1991.000000
# max    2019.000000       6.500000e+06      1.000000    33.540000  5461.000000
#
#              Price
# count  3499.000000
# mean      9.605247
# std      11.250112
# min       0.440000
# 25%       3.500000
# 50%       5.650000
# 75%      10.250000
# max      97.070000

# %%
df['Price']>10.25
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 3494    False
# 3495    False
# 3496    False
# 3497    False
# 3498    False
# Name: Price, Length: 3499, dtype: bool

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df.drop(columns='New_Price',inplace= True)

# %%
x =df.drop(columns='Price')
y=df['Price']

# %%
x.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type  Transmission Owner_Type  Mileage  Engine   Power Seats
# 0       CNG             0      First    26.60   998.0  58.16    5.0
# 1    Diesel             0      First    19.67  1582.0  126.2    5.0
# 2    Petrol             0      First    18.20  1199.0   88.7    5.0
# 3    Diesel             0      First    20.77  1248.0  88.76    7.0
# 4    Diesel             1     Second    15.20  1968.0  140.8    5.0

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
df.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
df.to_csv('cleaned_data')
